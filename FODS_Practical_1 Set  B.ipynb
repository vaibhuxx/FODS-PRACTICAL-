# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhuxx/FODS-PRACTICAL-/blob/Practical1/FODS_Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set B

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Q1: Download height and weight dataset and load the dataset from a given csv file into a data frame.
# Print first, last 10 rows and random 20 rows

# %%
import pandas as pd
import numpy as np
from random import sample

# %%
df = pd.read_csv('SOCR-HeightWeight.csv')
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
from google.colab import files
HW_uploaded= files.upload()
# Out:
#      <input type="file" id="files-c1ede2cf-efcf-4d98-9109-ff7c768925e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1ede2cf-efcf-4d98-9109-ff7c768925e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(HW_uploaded['SOCR-HeightWeight.csv']))
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
#First and Last 10 rows
df.head(10)
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
# 5      6        68.69784        123.3024
# 6      7        69.80204        141.4947
# 7      8        70.01472        136.4623
# 8      9        67.90265        112.3723
# 9     10        66.78236        120.6672

# %%
df.tail(10)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 24990  24991        69.97767        125.3672
# 24991  24992        71.91656        128.2840
# 24992  24993        70.96218        146.1936
# 24993  24994        66.19462        118.7974
# 24994  24995        67.21126        127.6603
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742

# %%
df.sample(n=20)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 11279  11280        67.77900        133.1513
# 8935    8936        68.33555        137.7148
# 10690  10691        65.73491        115.5253
# 15465  15466        68.20199        110.4711
# 17755  17756        65.73185        107.9237
# 6967    6968        67.71305        117.6067
# 15099  15100        68.99917        129.7717
# 3428    3429        68.80049        115.6403
# 13016  13017        68.35335        130.4412
# 3860    3861        69.15846        141.6059
# 7276    7277        70.24106        122.7590
# 20610  20611        72.75763        135.1411
# 19607  19608        68.02524        131.1121
# 471      472        70.40713        132.3684
# 2107    2108        66.91885        146.8505
# 3514    3515        67.07598        125.5866
# 1762    1763        68.13393        126.8874
# 20051  20052        68.41146        131.7994
# 13830  13831        66.76670        106.6478
# 2403    2404        66.96198        118.7229

# %% [markdown]
# Q2: Find shape,size,datatype of the dataframe object

# %%
#shape
df.shape
# Out:
# (25000, 3)

# %%
#SIZE
df.size
# Out:
# 75000

# %%
#datatype
df.dtypes
# Out:
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %% [markdown]
# Q3: View Basic statistical details of the data

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %% [markdown]
# Q4: Get number of observations, missing values and nan values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           25000 non-null  int64
#  1   Height(Inches)  25000 non-null  float64
#  2   Weight(Pounds)  25000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 586.1 KB

# %%
df.size
# Out:
# 75000

# %%
#missing values
df.isnull()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# 24995  False           False           False
# 24996  False           False           False
# 24997  False           False           False
# 24998  False           False           False
# 24999  False           False           False
#
# [25000 rows x 3 columns]

# %%
#NaN values
df.fillna("No Value Available", inplace = True)
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Index', 'Height(Inches)', 'Weight(Pounds)'], dtype='object')

# %% [markdown]
# Q5; Add columns to the dataframe "BMI" which is calculated as : weight/height^2

# %%
df["BMI"] = df['Weight(Pounds)']/(df['Height(Inches)']*df['Height(Inches)'])
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)       BMI
# 0          1        65.78331        112.9925  0.026111
# 1          2        71.51521        136.4873  0.026687
# 2          3        69.39874        153.0269  0.031773
# 3          4        68.21660        142.3354  0.030587
# 4          5        67.78781        144.2971  0.031402
# ...      ...             ...             ...       ...
# 24995  24996        69.50215        118.0312  0.024434
# 24996  24997        64.54826        120.1932  0.028848
# 24997  24998        64.69855        118.2655  0.028253
# 24998  24999        67.52918        132.2682  0.029005
# 24999  25000        68.87761        124.8742  0.026322
#
# [25000 rows x 4 columns]

# %% [markdown]
# Q6: Find maximum and minimum BMI

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)           BMI
# count  25000.000000    25000.000000    25000.000000  25000.000000
# mean   12500.500000       67.993114      127.079421      0.027482
# std     7217.022701        1.901679       11.660898      0.002207
# min        1.000000       60.278360       78.014760      0.018591
# 25%     6250.750000       66.704397      119.308675      0.025998
# 50%    12500.500000       67.995700      127.157750      0.027454
# 75%    18750.250000       69.272958      134.892850      0.028955
# max    25000.000000       75.152800      170.924000      0.037014

# %%
import matplotlib.pyplot as plt
df.plot(kind = "scatter", x= 'Height(Inches)', y = 'Weight(Pounds)')
#df.plot.scatter(x=['Height(Inches) ', y = 'Weight(Pounds)' ])
#df.scatter(df['Height(Inches)'], df['Weight(Pounds)'])
