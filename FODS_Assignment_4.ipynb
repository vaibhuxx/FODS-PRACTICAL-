# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhuxx/FODS-PRACTICAL-/blob/Practical-4/FODS_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SET A

# %%
#Q1

#import random as rd
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(25,10,25)
y = np.random.normal(25,10,25)
x
y
# Out:
# array([32.65704819, 19.63647886, 33.57732395, 44.42107495, 16.51944833,
#        27.7672973 , 35.49364469, 25.49400837, 16.8294325 ,  3.03712073,
#        37.7224495 , 24.14079914, 37.91701415, 26.62378841, 24.21892492,
#        22.69166375, 30.80678945, 32.95240668, 31.52279566, 23.35777231,
#        24.27652442, 20.15823989, 29.37296085, 19.58144362, 24.00293243])

# %%
plt.plot(x, linestyle='--',linewidth=2)


plt.xlabel("X Axis",fontdict = font1)
plt.ylabel("Y Axis",fontdict = font2)
plt.title("Random data array Data", loc = 'left')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

# %%
plt.scatter(x,y)

plt.xlabel("X Axis",fontdict = font2)
plt.ylabel("Y Axis",fontdict = font1)
plt.title("Random data array Data", loc = 'right')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

# %%
plt.hist(x,facecolor = "yellow",alpha=0.5,edgecolor='b',bins=50)

plt.xlabel("X Axis",fontdict = font2)
plt.ylabel("Y Axis",fontdict = font1)
plt.title("Random data array Data", loc = 'right')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

# %%
plt.boxplot(x,vert=False)

plt.xlabel("X Axis",fontdict = font1)
plt.ylabel("Y Axis",fontdict = font2)
plt.title("Random data array Data", loc = 'center')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

# %%
#Q2

q1 = np.quantile(x, 0.25)
q3 = np.quantile(x, 0.75)
med = np.median(x)
iqr = q3-q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
print(iqr, upper_bound, lower_bound)
# Out:
# 11.321040401323955 48.51785722932635 3.2336956240305312

# %%
outliers = x[(x <= lower_bound) | (x >= upper_bound)]
print('The following are the outliers in the boxplot:{}'.format(outliers))
# Out:
# The following are the outliers in the boxplot:[51.08337777]

# %%
sub = ["Maths","History","Geography","Science","CS"]
mrk = [90,87,92,87,89]
plt.pie(mrk,labels = sub)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb4013d5450>,
#   <matplotlib.patches.Wedge at 0x7fb4013d5b10>,
#   <matplotlib.patches.Wedge at 0x7fb4013d5810>,
#   <matplotlib.patches.Wedge at 0x7fb401394c90>,
#   <matplotlib.patches.Wedge at 0x7fb4013947d0>],
#  [Text(0.8853319778719253, 0.6528302144948448, 'Maths'),
#   Text(-0.33991867422268773, 1.046162174289766, 'History'),
#   Text(-1.0999725881656814, -0.007765647693040824, 'Geography'),
#   Text(-0.3251140200774818, -1.0508572091150439, 'Science'),
#   Text(0.8899186877588748, -0.646563785853741, 'CS')])

# %%
plt.bar(sub,mrk,color='g')
# Out:
# <BarContainer object of 5 artists>

# %%
#Q4
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
iris = pd.read_csv("Iris.csv")
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot('Species',data=iris)
plt.title("Iris Species Count")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Q5

ax=plt.subplots(1,1,figsize=(10,8))
iris['Species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.title("Iris Species %")
plt.show()

# %%
plt.figure(figsize = (10, 7))
x = df["SepalLengthCm"]
plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # SET B

# %%
fig = iris[iris.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='orange', label='Setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='blue', label='versicolor',ax=fig)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Petal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %%
df.plot(kind ="scatter",x ='SepalLengthCm',y ='PetalLengthCm')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.title('Boxplot of Features', size=20)
# Out:
# Text(0.5, 1.0, 'Boxplot of Features')

# %% [markdown]
# # SET C

# %%
#Q1

import pandas as pd
import seaborn as sns
iris = pd.read_csv("Iris.csv")
#Drop id column
iris = iris.drop('Id',axis=1)
sns.pairplot(iris,hue='Species')
